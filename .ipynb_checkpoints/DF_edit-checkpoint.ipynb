# %%
import pandas as pd

# %%
df = pd.read_excel("Dashboard - Project Tracking.xlsx",nrows = 14, skiprows = 1, index_col=0)

# %%
df
# Out:
#                            PG District Developer Category of Institution  \
# Site Identification Number
# 1                           A       D1      Hero                Hospital
# 2                           A       D2    Tepsol                 College
# 3                           B       D1   Archita                Hospital
# 4                           B       D3      Hero                 College
# 5                           B       D3    Tepsol                 College
# 6                           A       D1   Archita                 College
# 7                           E       D1      Hero                 College
# 8                           D       D3    Tepsol                 College
# 9                           E       D3   Archita                Hospital
# 10                          E       D2      Hero                 College
# 11                          D       D2    Tepsol                Hospital
# ...

# %%
df.describe()
# Out:
#        Estimated Capacity   CPBG Amount  Finalised SPV Capacity  \
# count           14.000000  1.400000e+01               14.000000
# mean           289.500000  7.237500e+05              281.285714
# std            135.584632  3.389616e+05              132.544581
# min             75.000000  1.875000e+05               69.000000
# 25%            158.000000  3.950000e+05              166.500000
# 50%            324.000000  8.100000e+05              287.500000
# 75%            373.750000  9.343750e+05              395.750000
# max            485.000000  1.212500e+06              504.000000
#
#        Inc / Dec % wrt estimated  Extension provided for CP Fulfilment  \
# count                  14.000000                             14.000000
# mean                    0.022464                              1.928571
# std                     0.264532                              4.937522
# min                    -0.410876                              0.000000
# ...
